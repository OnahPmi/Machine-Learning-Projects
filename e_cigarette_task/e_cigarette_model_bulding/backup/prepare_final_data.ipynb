# %%
import pandas as pd

# %%
df = pd.read_csv("prepared_data.csv")
df.head(5)
# Out:
#    gender  age(year)  race_and_hispanic_origin  country_of_birth  \
# 0     2.0       48.0                       3.0               1.0
# 1     1.0       16.0                       4.0               1.0
# 2     1.0       64.0                       4.0               1.0
# 3     1.0       61.0                       1.0               1.0
# 4     1.0       31.0                       4.0               1.0
#
#    usa_citizenship  highest_education_grade_received  marital_status  \
# 0              1.0                               3.0             1.0
# 1              1.0                               4.0             1.0
# 2              1.0                               4.0             1.0
# 3              1.0                               3.0             1.0
# 4              1.0                               4.0             5.0
#
#    no_of_people_in_the_household  family_size  total_family_income  \
# 0                            4.0          4.0                  5.0
# ...

# %%
df = df[df["presence_of_cancer/malignancy"] == 2]
df.drop(["presence_of_cancer/malignancy"], axis=1, inplace=True)

df.to_csv("final_data.csv", index=False)
